# %% [markdown]
# # Master Your Logic Building — Standalone Code Practice
#
# Every question is a **separate code cell**. The style is beginner-friendly: `input()` → logic → `print()`.
#
# For recursion problems, a function is included because recursion requires a function.

# %% [markdown]
# # PHASE 1

# %% [markdown]
# ## Q1. Positive, Negative or Zero

# %%
n = int(input("Enter a number: "))

if n > 0:
    print("Positive")
elif n < 0:
    print("Negative")
else:
    print("Zero")

# %% [markdown]
# ## Q2. Even or Odd

# %%
n = int(input("Enter a number: "))

if n % 2 == 0:
    print("Even")
else:
    print("Odd")

# %% [markdown]
# ## Q3. Divisible by 5

# %%
n = int(input("Enter a number: "))

if n % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")

# %% [markdown]
# ## Q4. Divisible by Both 3 and 5

# %%
n = int(input("Enter a number: "))

if n % 3 == 0 and n % 5 == 0:
    print("Divisible by both 3 and 5")
else:
    print("Not divisible by both")

# %% [markdown]
# ## Q5. Leap Year

# %%
year = int(input("Enter a year: "))

if year % 400 == 0:
    print("Leap year")
elif year % 100 == 0:
    print("Not a leap year")
elif year % 4 == 0:
    print("Leap year")
else:
    print("Not a leap year")

# %% [markdown]
# ## Q6. Larger of Two Numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Larger:", a)
else:
    print("Larger:", b)

# %% [markdown]
# ## Q7. Largest of Three Numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest:", a)
elif b >= a and b >= c:
    print("Largest:", b)
else:
    print("Largest:", c)

# %% [markdown]
# ## Q8. Temperature: Cold, Warm or Hot

# %%
temperature = int(input("Enter temperature: "))

if temperature < 15:
    print("Cold")
elif temperature <= 30:
    print("Warm")
else:
    print("Hot")

# %% [markdown]
# ## Q9. Vowel or Consonant

# %%
ch = input("Enter a character: ")

if ch.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")

# %% [markdown]
# ## Q10. Uppercase, Lowercase, Digit or Special Character

# %%
ch = input("Enter a character: ")

if ch.isupper():
    print("Uppercase")
elif ch.islower():
    print("Lowercase")
elif ch.isdigit():
    print("Digit")
else:
    print("Special character")

# %% [markdown]
# ## Q11. Valid Triangle

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))
c = int(input("Enter c: "))

# %% [markdown]
# ## Q12. Type of Triangle

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))
c = int(input("Enter c: "))

    if not p1_11(a,b,c): return "Invalid"
    if a==b==c: return "Equilateral"
    if a==b or b==c or a==c: return "Isosceles"
    print("Scalene")

# %% [markdown]
# ## Q13. Grade from Marks

# %%
m = int(input("Enter m: "))

    if not 0 <= m <= 100: return "Invalid"
    print("A" if m>=90 else "B" if m>=75 else "C" if m>=60 else "D" if m>=40 else "F")

# %% [markdown]
# ## Q14. Multiple of the Other

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

    if a==0 or b==0: return False
    print(a%b==0 or b%a==0)

# %% [markdown]
# ## Q15. Greeting Based on Hour

# %%
h = int(input("Enter h: "))

    print("Good Morning" if 5<=h<12 else "Good Afternoon" if h<17 else "Good Evening" if h<21 else "Good Night")

# %% [markdown]
# ## Q16. Voting Eligibility

# %%
age = int(input("Enter age: "))

# %% [markdown]
# ## Q17. Even/Odd Combination

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

    print("Both Even" if a%2==0 and b%2==0 else "Both Odd" if a%2 and b%2 else "One Even, One Odd")

# %% [markdown]
# ## Q18. Alphabet: a-m or n-z

# %%
ch = input("Enter ch: ")

    c=ch.lower()
    print("a-m" if 'a'<=c<='m' else "n-z" if 'n'<=c<='z' else "Not alphabet")

# %% [markdown]
# ## Q19. Day Number to Day Name

# %%
day = int(input("Enter day: "))

    names=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
    print(names[day-1] if 1<=day<=7 else "Invalid")

# %% [markdown]
# ## Q20. Days in a Month

# %%
month = int(input("Enter month: "))

    days={1:31,2:28,3:31,4:30,5:31,6:30,7:31,8:31,9:30,10:31,11:30,12:31}
    print(days.get(month,"Invalid"))

# %% [markdown]
# ## Q21. Distinct Digits in 3-Digit Number

# %%
n = int(input("Enter n: "))

    a,b,c=map(int,f"{abs(n):03d}")
    print(len({a,b,c})==3)

# %% [markdown]
# ## Q22. Middle Digit Comparison

# %%
n = int(input("Enter n: "))

    a,b,c=map(int,f"{abs(n):03d}")
    print("Largest" if b>a and b>c else "Smallest" if b<a and b<c else "Neither")

# %% [markdown]
# ## Q23. First and Last Digit Equal

# %%
n = int(input("Enter n: "))

    s=f"{abs(n):04d}"; return s[0]==s[-1]

# %% [markdown]
# ## Q24. Number of Digits Category

# %%
n = int(input("Enter n: "))

    n=abs(n)
    print("Single-digit" if n<10 else "Double-digit" if n<100 else "Multi-digit")

# %% [markdown]
# ## Q25. Multiple of 7 or Ends in 7

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q26. Quadrant of a Point

# %%
x = int(input("Enter x: "))
y = int(input("Enter y: "))

    if x==0 and y==0: return "Origin"
    if x==0: return "Y-axis"
    if y==0: return "X-axis"
    print("Q1" if x>0 and y>0 else "Q2" if x<0<y else "Q3" if x<0 and y<0 else "Q4")

# %% [markdown]
# ## Q27. Currency Note Divisibility

# %%
amount = int(input("Enter amount: "))

# %% [markdown]
# ## Q28. Number in Range 100–999

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q29. Third Angle of Triangle

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

# %% [markdown]
# ## Q30. Perfect Square Without sqrt

# %%
n = int(input("Enter n: "))

    if n<0: return False
    r=isqrt(n); return r*r==n

# %% [markdown]
# ## Q31. Letter, Digit or Neither

# %%
ch = input("Enter ch: ")

# %% [markdown]
# ## Q32. FizzBuzz

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q33. Median of Three Numbers

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))
c = int(input("Enter c: "))

# %% [markdown]
# ## Q34. AM or PM

# %%
h = int(input("Enter h: "))
m = int(input("Enter m: "))

# %% [markdown]
# ## Q35. Tax Eligibility

# %%
age = int(input("Enter age: "))
income = int(input("Enter income: "))

# %% [markdown]
# ## Q36. Positive Numbers and Sum < 100

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

# %% [markdown]
# ## Q37. Digit to Word

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q38. Weekday or Weekend

# %%
day = int(input("Enter day: "))

# %% [markdown]
# ## Q39. Electricity Bill by Slabs

# %%
units = int(input("Enter units: "))

    if units<=100: return units*5
    if units<=200: return 100*5+(units-100)*7
    print(100*5+100*7+(units-200)*10)

# %% [markdown]
# ## Q40. Basic Password Validation

# %%
password = input("Enter password: ")

# %% [markdown]
# ## Q41. Point on Axis or Origin

# %%
x = int(input("Enter x: "))
y = int(input("Enter y: "))

    print("Origin" if x==0 and y==0 else "X-axis" if y==0 else "Y-axis" if x==0 else "Neither")

# %% [markdown]
# ## Q42. Pythagorean Triplet

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))
c = int(input("Enter c: "))

    a,b,c=sorted([a,b,c]); return a*a+b*b==c*c

# %% [markdown]
# ## Q43. Valid Calendar Date

# %%
day = int(input("Enter day: "))
month = int(input("Enter month: "))
year = int(input("Enter year: "))

    days={1:31,2:29 if year%400==0 or (year%4==0 and year%100!=0) else 28,3:31,4:30,5:31,6:30,7:31,8:31,9:30,10:31,11:30,12:31}
    print(month in days and 1<=day<=days[month])

# %% [markdown]
# ## Q44. Smaller Clock-Hand Angle

# %%
h = int(input("Enter h: "))
m = int(input("Enter m: "))

    hour_angle=(h%12)*30+m*0.5
    minute_angle=m*6
    d=abs(hour_angle-minute_angle)
    print(min(d,360-d))

# %% [markdown]
# ## Q45. Arithmetic Progression

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))
c = int(input("Enter c: "))

# %% [markdown]
# ## Q46. Geometric Progression

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))
c = int(input("Enter c: "))

# %% [markdown]
# ## Q47. First + Last = Middle Digit

# %%
n = int(input("Enter n: "))

    s=f"{abs(n):03d}"; return int(s[0])+int(s[2])==int(s[1])

# %% [markdown]
# ## Q48. Digit Sum Greater Than Product

# %%
n = int(input("Enter n: "))

    digits=[int(x) for x in str(abs(n))]
    print(sum(digits)>__import__("math").prod(digits))

# %% [markdown]
# ## Q49. Which Date Comes First

# %%
d1 = int(input("Enter d1: "))
m1 = int(input("Enter m1: "))
d2 = int(input("Enter d2: "))
m2 = int(input("Enter m2: "))

# %% [markdown]
# ## Q50. Century of a Year

# %%
year = int(input("Enter year: "))

    century=(year-1)//100+1
    suffix="th" if 10<century%100<14 else {1:"st",2:"nd",3:"rd"}.get(century%10,"th")
    print(f"{century}{suffix} century")

# %% [markdown]
# # PHASE 2

# %% [markdown]
# ## Q1. Print 1 to 10

# %% [markdown]
# ## Q2. Even Numbers 1 to 100

# %% [markdown]
# ## Q3. Odd Numbers 1 to 100

# %% [markdown]
# ## Q4. Print 10 Down to 1

# %% [markdown]
# ## Q5. Multiplication Table

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q6. Sum of First n Natural Numbers

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q7. Sum of Even Numbers

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q8. Sum of Odd Numbers

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q9. Factorial

# %%
n = int(input("Enter n: "))

    r=1
    for i in range(1,n+1): r*=i
    print(r)

# %% [markdown]
# ## Q10. Product of Digits

# %%
n = int(input("Enter n: "))

    p=1
    for d in str(abs(n)): p*=int(d)
    print(p)

# %% [markdown]
# ## Q11. Count Digits

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q12. Reverse a Number

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q13. Number Palindrome

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q14. Sum of Digits

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q15. Armstrong Number

# %%
n = int(input("Enter n: "))

    ds=str(abs(n)); k=len(ds); return sum(int(d)**k for d in ds)==n

# %% [markdown]
# ## Q16. Perfect Number

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q17. Prime Numbers 1 to 100

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

# %% [markdown]
# ## Q18. Prime Check

# %%
n = int(input("Enter n: "))

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

    if n<2: return False
    for i in range(2,isqrt(n)+1):
        if n%i==0: return False
    print(True)

# %% [markdown]
# ## Q19. Fibonacci Series

# %%
n = int(input("Enter n: "))

    a,b=0,1; out=[]
    for _ in range(n): out.append(a); a,b=b,a+b
    print(out)

# %% [markdown]
# ## Q20. Sum of Fibonacci Terms

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q21. Squares 1 to n

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q22. Cubes 1 to n

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q23. Numbers Divisible by 7

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

# %% [markdown]
# ## Q24. HCF/GCD

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

def gcd(a, b):
    while b:
        a, b = b, a % b
    return abs(a)

    while b: a,b=b,a%b
    print(abs(a))

# %% [markdown]
# ## Q25. LCM

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

def gcd(a, b):
    while b:
        a, b = b, a % b
    return abs(a)

# %% [markdown]
# ## Q26. All Factors

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q27. Sum of Factors

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q28. Strong Number

# %%
n = int(input("Enter n: "))

    def fact(x):
        r=1
        for i in range(1,x+1): r*=i
        print(r)
    print(sum(fact(int(d)) for d in str(abs(n)))==n)

# %% [markdown]
# ## Q29. Arithmetic Progression Terms

# %%
a = int(input("Enter first value: "))
d = int(input("Enter d: "))
n = int(input("Enter n: "))

# %% [markdown]
# ## Q30. Geometric Progression Terms

# %%
a = int(input("Enter first value: "))
r = int(input("Enter r: "))
n = int(input("Enter n: "))

    out=[]; x=a
    for _ in range(n): out.append(x); x*=r
    print(out)

# %% [markdown]
# ## Q31. Increasing Star Triangle

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q32. Decreasing Star Triangle

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q33. Star Square

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q34. Number Triangle

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q35. Reverse Number Triangle

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q36. Centered Star Pyramid

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q37. Inverted Star Pyramid

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q38. Repeated Row Numbers

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q39. Number Square

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q40. Binary 0-1 Pattern

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q41. Numbers with Even Digit Sum

# %% [markdown]
# ## Q42. Divisible by 7 but Not 5

# %% [markdown]
# ## Q43. Palindromes 1 to 500

# %% [markdown]
# ## Q44. Digit Sum Multiple of 3

# %% [markdown]
# ## Q45. Smallest and Largest Digit

# %%
n = int(input("Enter n: "))

    ds=[int(d) for d in str(abs(n))]
    print(min(ds),max(ds))

# %% [markdown]
# ## Q46. Binary Representation with Even Number of 1s

# %%
n = int(input("Enter n: "))

    print([i for i in range(1,n+1) if bin(i).count("1")%2==0])

# %% [markdown]
# ## Q47. i and i² Pattern

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q48. Factorials 1 to n

# %%
n = int(input("Enter n: "))

    print([p2_9(i) for i in range(1,n+1)])

# %% [markdown]
# ## Q49. Odd and Even Digit Sums

# %%
n = int(input("Enter n: "))

    odd=even=0
    for d in str(abs(n)):
        if int(d)%2: odd+=int(d)
        else: even+=int(d)
    print(odd,even)

# %% [markdown]
# ## Q50. Sum of Non-Zero Inputs

# %%
nums = list(map(int, input("Enter numbers separated by spaces: ").split()))

    print(sum(x for x in nums if x!=0))

# %% [markdown]
# # PHASE 3

# %% [markdown]
# ## Q1. Print 1 to n Recursively

# %%
def p3_1(n):
    if n==0: return []
    return p3_1(n-1)+[n]

n = int(input("Enter n: "))
print(p3_1(n))

# %% [markdown]
# ## Q2. Print n to 1 Recursively

# %%
def p3_2(n):
    if n==0: return []
    return [n]+p3_2(n-1)

n = int(input("Enter n: "))
print(p3_2(n))

# %% [markdown]
# ## Q3. Even Numbers Recursively

# %%
def p3_3(n):
    if n==0: return []
    return p3_3(n-1)+([n] if n%2==0 else [])

n = int(input("Enter n: "))
print(p3_3(n))

# %% [markdown]
# ## Q4. Odd Numbers Recursively

# %%
def p3_4(n):
    if n==0: return []
    return p3_4(n-1)+([n] if n%2 else [])

n = int(input("Enter n: "))
print(p3_4(n))

# %% [markdown]
# ## Q5. Sum of First n Numbers

# %%
def p3_5(n): return 0 if n==0 else n+p3_5(n-1)

n = int(input("Enter n: "))
print(p3_5(n))

# %% [markdown]
# ## Q6. Recursive Factorial

# %%
def p3_6(n): return 1 if n<=1 else n*p3_6(n-1)

n = int(input("Enter n: "))
print(p3_6(n))

# %% [markdown]
# ## Q7. Recursive Power

# %%
def p3_7(x,n): return 1 if n==0 else x*p3_7(x,n-1)

x = int(input("Enter x: "))
n = int(input("Enter n: "))
print(p3_7(x, n))

# %% [markdown]
# ## Q8. Nth Fibonacci Number

# %%
def p3_8(n): return n if n<=1 else p3_8(n-1)+p3_8(n-2)

n = int(input("Enter n: "))
print(p3_8(n))

# %% [markdown]
# ## Q9. Fibonacci Series Recursively

# %%
def p3_9(n):
    return p3_19(0,1,n)

n = int(input("Enter n: "))
print(p3_9(n))

# %% [markdown]
# ## Q10. Recursive Digit Sum

# %%
def p3_10(n): return n if n<10 else n%10+p3_10(n//10)

n = int(input("Enter n: "))
print(p3_10(n))

# %% [markdown]
# ## Q11. Recursive Digit Count

# %%
def p3_11(n): return 1 if abs(n)<10 else 1+p3_11(n//10)

n = int(input("Enter n: "))
print(p3_11(n))

# %% [markdown]
# ## Q12. Reverse Number Recursively

# %%
def p3_12(n):
    if n<10: return n
    return (n%10)*10**(p3_11(n)-1)+p3_12(n//10)

n = int(input("Enter n: "))
print(p3_12(n))

# %% [markdown]
# ## Q13. Recursive Palindrome

# %%
def p3_13(s): return s==s[::-1]

s = input("Enter s: ")
print(p3_13(s))

# %% [markdown]
# ## Q14. Recursive Product of Digits

# %%
def p3_14(n):
    return abs(n) if n<10 else abs(n)%10*p3_14(n//10)

n = int(input("Enter n: "))
print(p3_14(n))

# %% [markdown]
# ## Q15. Recursive GCD

# %%
def p3_15(a,b):
    return abs(a) if b==0 else p3_15(b,a%b)

a = int(input("Enter a: "))
b = int(input("Enter b: "))
print(p3_15(a, b))

# %% [markdown]
# ## Q16. Decimal to Binary Recursively

# %%
def p3_16(n):
    if n<2: return str(n)
    return p3_16(n//2)+str(n%2)

n = int(input("Enter n: "))
print(p3_16(n))

# %% [markdown]
# ## Q17. Digits in Words Recursively

# %%
def p3_17(n):
    words=["zero","one","two","three","four","five","six","seven","eight","nine"]
    if n<10: return words[n]
    return p3_17(n//10)+" "+words[n%10]

n = int(input("Enter n: "))
print(p3_17(n))

# %% [markdown]
# ## Q18. Sum of First n Even Numbers

# %%
def p3_18(n):
    return 0 if n==0 else 2*n+p3_18(n-1)

n = int(input("Enter n: "))
print(p3_18(n))

# %% [markdown]
# ## Q19. Fibonacci Helper

# %%
def p3_19(a,b,n):
    if n==0: return []
    return [a]+p3_19(b,a+b,n-1)

a = int(input("Enter a: "))
b = int(input("Enter b: "))
n = int(input("Enter n: "))
print(p3_19(a, b, n))

# %% [markdown]
# ## Q20. Recursive nCr

# %%
def p3_20(n,r):
    if r==0 or r==n: return 1
    return p3_20(n-1,r-1)+p3_20(n-1,r)

n = int(input("Enter n: "))
r = int(input("Enter r: "))
print(p3_20(n, r))

# %% [markdown]
# ## Q21. Line of Stars Recursively

# %%
def p3_21(n): return "*"*n

n = int(input("Enter n: "))
print(p3_21(n))
# Out:
# *******

# %% [markdown]
# ## Q22. Star Square Recursively

# %%
def p3_22(n):
    return ["*"*n for _ in range(n)] if n>0 else []

n = int(input("Enter n: "))
print(p3_22(n))
# Out:
# ['*******', '*******', '*******', '*******', '*******', '*******', '*******']

# %% [markdown]
# ## Q23. Top-Down Star Triangle

# %%
def p3_23(n):
    if n==0: return []
    return p3_23(n-1)+["*"*n]

n = int(input("Enter n: "))
print(p3_23(n))

# %% [markdown]
# ## Q24. Bottom-Up Star Triangle

# %%
def p3_24(n):
    if n==0: return []
    return ["*"*n]+p3_24(n-1)

n = int(input("Enter n: "))
print(p3_24(n))
# Out:
# ['********', '*******', '******', '*****', '****', '***', '**', '*']

# %% [markdown]
# ## Q25. Recursive Number Pattern

# %%
def p3_25(n):
    if n==0: return []
    return p3_25(n-1)+[" ".join(str(i) for i in range(1,n+1))]

n = int(input("Enter n: "))
print(p3_25(n))

# %% [markdown]
# ## Q26. Reverse Triangle Recursively

# %%
def p3_26(n):
    if n==0: return []
    return ["*"*n]+p3_26(n-1)

n = int(input("Enter n: "))
print(p3_26(n))

# %% [markdown]
# ## Q27. Multiplication Table Recursively

# %%
def p3_27(n): return p2_5(n)

n = int(input("Enter n: "))
print(p3_27(n))

# %% [markdown]
# ## Q28. Increasing and Decreasing in Same Function

# %%
def p3_28(n):
    if n==0: return []
    return [n]+p3_28(n-1)+[n]

n = int(input("Enter n: "))
print(p3_28(n))

# %% [markdown]
# ## Q29. Recursive Sum Series

# %%
def p3_29(n): return p3_5(n)

n = int(input("Enter n: "))
print(p3_29(n))

# %% [markdown]
# ## Q30. Recursive Character Pattern

# %%
def p3_30(n):
    if n==0: return []
    return p3_30(n-1)+[chr(64+i) for i in range(1,n+1)]

n = int(input("Enter n: "))
print(p3_30(n))

# %% [markdown]
# ## Q31. Reverse String Recursively

# %%
def p3_31(s): return s[::-1]

s = input("Enter s: ")
print(p3_31(s))

# %% [markdown]
# ## Q32. String Palindrome Recursively

# %%
def p3_32(s): return s==s[::-1]

s = input("Enter s: ")
print(p3_32(s))

# %% [markdown]
# ## Q33. Count Vowels Recursively

# %%
def p3_33(s): return sum(1 for c in s.lower() if c in "aeiou")

s = input("Enter s: ")
print(p3_33(s))

# %% [markdown]
# ## Q34. Remove Spaces Recursively

# %%
def p3_34(s): return s.replace(" ","")

s = input("Enter s: ")
print(p3_34(s))

# %% [markdown]
# ## Q35. Replace Character Recursively

# %%
def p3_35(s,a="a",x="x"): return "".join(x if c==a else c for c in s)

s = input("Enter s: ")
a = int(input("Enter a: "))
x = int(input("Enter x: "))
print(p3_35(s, a, x))

# %% [markdown]
# ## Q36. Remove Character Recursively

# %%
def p3_36(s,a): return "".join(c for c in s if c!=a)

s = input("Enter s: ")
a = int(input("Enter a: "))
print(p3_36(s, a))

# %% [markdown]
# ## Q37. Print Characters Recursively

# %%
def p3_37(s): return list(s)

s = input("Enter s: ")
print(p3_37(s))

# %% [markdown]
# ## Q38. Print String Reverse Recursively

# %%
def p3_38(s): return s[::-1]

s = input("Enter s: ")
print(p3_38(s))

# %% [markdown]
# ## Q39. Uppercase Recursively

# %%
def p3_39(s): return s.upper()

s = input("Enter s: ")
print(p3_39(s))

# %% [markdown]
# ## Q40. Count Consonants and Vowels Recursively

# %%
def p3_40(s):
    v=sum(c.lower() in "aeiou" for c in s if c.isalpha())
    c=sum(c.isalpha() and c.lower() not in "aeiou" for c in s)
    return c,v

s = input("Enter s: ")
print(p3_40(s))

# %% [markdown]
# # PHASE 4

# %% [markdown]
# ## Q1. Question 1

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q2. Question 2

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q3. Question 3

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q4. Question 4

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q5. Question 5

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q6. Question 6

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q7. Question 7

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q8. Question 8

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q9. Question 9

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q10. Question 10

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
k = int(input("Enter k: "))

# %% [markdown]
# ## Q11. Question 11

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
x = int(input("Enter x: "))

# %% [markdown]
# ## Q12. Question 12

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
x = int(input("Enter x: "))

# %% [markdown]
# ## Q13. Question 13

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
x = int(input("Enter x: "))

    print(a.index(x) if x in a else -1)

# %% [markdown]
# ## Q14. Question 14

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
x = int(input("Enter x: "))

    print(len(a)-1-a[::-1].index(x) if x in a else -1)

# %% [markdown]
# ## Q15. Question 15

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q16. Question 16

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q17. Question 17

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q18. Question 18

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

# %% [markdown]
# ## Q19. Question 19

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q20. Question 20

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

# %% [markdown]
# ## Q21. Question 21

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q22. Question 22

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q23. Question 23

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q24. Question 24

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q25. Question 25

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

    a=a[:]
    if a: a[0],a[-1]=a[-1],a[0]
    print(a)

# %% [markdown]
# ## Q26. Question 26

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q27. Question 27

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q28. Question 28

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q29. Question 29

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

    a=a[:]
    for i in range(0,len(a)-1,2): a[i],a[i+1]=a[i+1],a[i]
    print(a)

# %% [markdown]
# ## Q30. Question 30

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q31. Question 31

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q32. Question 32

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q33. Question 33

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q34. Question 34

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q35. Question 35

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q36. Question 36

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q37. Question 37

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q38. Question 38

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q39. Question 39

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q40. Question 40

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q41. Question 41

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q42. Question 42

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q43. Question 43

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

    vals=sorted(set(a),reverse=True); return vals[1] if len(vals)>=2 else None

# %% [markdown]
# ## Q44. Question 44

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

    vals=sorted(set(a)); return vals[1] if len(vals)>=2 else None

# %% [markdown]
# ## Q45. Question 45

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q46. Question 46

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

    if len(a)<=2: return 0
    print(sum(a)-max(a)-min(a))

# %% [markdown]
# ## Q47. Question 47

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
k = int(input("Enter k: "))

    print(sum(1 for i in range(len(a)) for j in range(i+1,len(a)) if a[i]+a[j]==k))

# %% [markdown]
# ## Q48. Question 48

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q49. Question 49

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q50. Question 50

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# # PHASE 5

# %% [markdown]
# ## Q1. Question 1

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q2. Question 2

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q3. Question 3

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q4. Question 4

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q5. Question 5

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q6. Question 6

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q7. Question 7

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

# %% [markdown]
# ## Q8. Question 8

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

# %% [markdown]
# ## Q9. Question 9

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q10. Question 10

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q11. Question 11

# %%
s = input("Enter s: ")

    print(sum(c.lower() in "aeiou" for c in s),sum(c.isalpha() and c.lower() not in "aeiou" for c in s))

# %% [markdown]
# ## Q12. Question 12

# %%
s = input("Enter s: ")

    print(sum(c.isalpha() for c in s),sum(c.isdigit() for c in s),sum(not c.isalnum() and not c.isspace() for c in s))

# %% [markdown]
# ## Q13. Question 13

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q14. Question 14

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q15. Question 15

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q16. Question 16

# %%
s = input("Enter s: ")
ch = input("Enter ch: ")

# %% [markdown]
# ## Q17. Question 17

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q18. Question 18

# %%
s = input("Enter s: ")

    print(sum(1 for i in range(len(s)) for j in range(i+1,len(s)) if s[i]==s[j]))

# %% [markdown]
# ## Q19. Question 19

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q20. Question 20

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q21. Question 21

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q22. Question 22

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q23. Question 23

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q24. Question 24

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q25. Question 25

# %%
a = int(input("Enter first value: "))
b = int(input("Enter second value: "))

# %% [markdown]
# ## Q26. Question 26

# %%
s = input("Enter s: ")

    n=len(s); return s[(n-1)//2:(n//2)+1]

# %% [markdown]
# ## Q27. Question 27

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q28. Question 28

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q29. Question 29

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q30. Question 30

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q31. Question 31

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q32. Question 32

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q33. Question 33

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q34. Question 34

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q35. Question 35

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q36. Question 36

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q37. Question 37

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q38. Question 38

# %%
s = input("Enter s: ")

    out=""
    for c in s:
        if not out or out[-1]!=c: out+=c
    print(out)

# %% [markdown]
# ## Q39. Question 39

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q40. Question 40

# %%
s = input("Enter s: ")

    print("".join(chr(ord(c)+1) if c.isalpha() else c for c in s))

# %% [markdown]
# ## Q41. Question 41

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q42. Question 42

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q43. Question 43

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q44. Question 44

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q45. Question 45

# %%
s = input("Enter s: ")

    w=s.split()
    if len(w)>=2: w[0],w[-1]=w[-1],w[0]
    print(" ".join(w))

# %% [markdown]
# ## Q46. Question 46

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q47. Question 47

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q48. Question 48

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q49. Question 49

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q50. Question 50

# %%
s = input("Enter s: ")

# %% [markdown]
# # PHASE 6

# %% [markdown]
# ## Q1. Question 1

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q2. Question 2

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q3. Question 3

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q4. Question 4

# %% [markdown]
# ## Q5. Question 5

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q6. Question 6

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q7. Question 7

# %%
n = int(input("Enter n: "))

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

# %% [markdown]
# ## Q8. Question 8

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q9. Question 9

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q10. Question 10

# %%
n = int(input("Enter n: "))

# %% [markdown]
# ## Q11. Question 11

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

    print(len(a)==len(b) and Counter(a)==Counter(b))

# %% [markdown]
# ## Q12. Question 12

# %%
s = input("Enter s: ")

    print([(w,sum(c.lower() in "aeiou" for c in w)) for w in s.split()])

# %% [markdown]
# ## Q13. Question 13

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q14. Question 14

# %%
s = input("Enter s: ")

    pos={"a":1,"e":2,"i":3,"o":4,"u":5}
    print("".join(str(pos[c.lower()]) if c.lower() in pos else c for c in s))

# %% [markdown]
# ## Q15. Question 15

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q16. Question 16

# %%
s = input("Enter s: ")

# %% [markdown]
# ## Q17. Question 17

# %%
s = input("Enter s: ")

    w=s.split()
    print(" ".join(x.swapcase() if i%2==0 else x for i,x in enumerate(w)))

# %% [markdown]
# ## Q18. Question 18

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q19. Question 19

# %%
s = input("Enter s: ")

    print(max(s.split(),key=lambda w:sum(c.lower() in "aeiou" for c in w),default=""))

# %% [markdown]
# ## Q20. Question 20

# %%
s = input("Enter s: ")

    seen=set(); out=[]
    for w in s.split():
        if w not in seen: out.append(w); seen.add(w)
    print(" ".join(out))

# %% [markdown]
# ## Q21. Question 21

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q22. Question 22

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q23. Question 23

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q24. Question 24

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q25. Question 25

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

    out=[]; zeros=0
    for x in a:
        if x==0: zeros+=1
        else: out.append(x)
    print(out+[0]*zeros)

# %% [markdown]
# ## Q26. Question 26

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q27. Question 27

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
b = list(map(int, input("Enter second array/string value: ").split()))

# %% [markdown]
# ## Q28. Question 28

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q29. Question 29

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))

# %% [markdown]
# ## Q30. Question 30

# %%
a = list(map(int, input("Enter array elements separated by spaces: ").split()))
